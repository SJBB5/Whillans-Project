# %%
# Sam Brown
# sam_brown@mines.edu
# June 18
# Goal: Neural Net for predicting time until next event

# Directory
import sys
sys.path.append("/Users/sambrown04/Documents/SURF/whillans-surf/notebooks/SURF")

# Imports
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("/Users/sambrown04/Documents/SURF/Preproc_data/averages_events_2011-13.csv")
df = df.iloc[1:-1] # account for shift to get mins until
df.head()
# Out:
#    pre_slip_area  total_delta           start_time  slip_severity  \
# 1     126.125599     0.312254  2011-01-11 19:10:00   6.707494e-07
# 2     138.865041     0.334800  2011-01-12 08:45:00   6.132234e-07
# 3      90.950510     0.303650  2011-01-12 21:25:00   9.796908e-07
# 4     128.884896     0.324098  2011-01-13 10:35:00   7.178703e-07
# 5     120.203366     0.473986  2011-01-14 09:40:00   1.042288e-06
#
#    tide_height  tide_change  form_factor  mins_since  mins_until  h_event
# 1   -19.514214    -0.246130     1.647468       665.0       815.0        0
# 2    19.337788    -0.079343     1.702534       815.0       760.0        1
# 3   -53.653778    -0.151990     1.702534       760.0       790.0        0
# 4    25.038245    -0.115554     2.101911       790.0      1385.0        1
# 5    53.094581    -0.159486     2.778525      1385.0       605.0        1

# %%
# Define features and target
X = df[['mins_since', 'tide_change', 'tide_height', 'h_event', 'form_factor', 'slip_severity', 'total_delta', 'pre_slip_area']]
y = df['mins_until'].values.reshape(-1,1)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = .2, random_state = 42)

# Standardize
x_scaler = StandardScaler()
X_train_scaled = x_scaler.fit_transform(X_train)
X_test_scaled = x_scaler.transform(X_test)

y_scaler = StandardScaler()
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.reshape(-1, 1))


# Pytorch tensors 
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train_scaled, dtype=torch.float32)

X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test_scaled, dtype=torch.float32)

# %%
# Neural Net
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(8, 32)
        self.fc2 = nn.Linear(32, 16)
        self.fc3 = nn.Linear(16,1)

    def forward(self,x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x) # Regressing
        return x

# %%
model = Net()
criterion = nn.MSELoss() # Loss for regression
optimizer = optim.Adam(model.parameters(), lr = .01)

# Training loop
epochs = 200
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad() # Clears grad

    # Predictions and loss
    outputs = model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)

    # Backprop
    loss.backward()

    # Update params
    optimizer.step()
    
    if (epoch+1) % 20 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [20/200], Loss: 0.8464
# Epoch [40/200], Loss: 0.7180
# Epoch [60/200], Loss: 0.6324
# Epoch [80/200], Loss: 0.5837
# Epoch [100/200], Loss: 0.5465
# Epoch [120/200], Loss: 0.5235
# Epoch [140/200], Loss: 0.5068
# Epoch [160/200], Loss: 0.4894
# Epoch [180/200], Loss: 0.4722
# Epoch [200/200], Loss: 0.4625

# %%
# Eval
model.eval()
with torch.no_grad():
    y_pred_scaled = model(X_test_tensor)
    y_pred = y_scaler.inverse_transform(y_pred_scaled.numpy())
    y_test_orig = y_scaler.inverse_transform(y_test_tensor.numpy())

# predictions vs actual
print("\nPredictions vs Actual:")
for pred, actual in zip(y_pred.flatten(), y_test_orig.flatten()):
    print(f"Predicted: {pred:.2f}, Actual: {actual:.2f}")
# Out:
# Predictions vs Actual:
# Predicted: 1332.87, Actual: 1470.00
# Predicted: 910.41, Actual: 750.00
# Predicted: 1070.01, Actual: 870.75
# Predicted: 958.19, Actual: 660.00
# Predicted: 1352.81, Actual: 1319.25
# Predicted: 680.28, Actual: 515.00
# Predicted: 1166.99, Actual: 1475.75
# Predicted: 1271.58, Actual: 1395.00
# Predicted: 564.14, Actual: 606.50
# Predicted: 409.05, Actual: 633.25
# Predicted: 911.76, Actual: 776.50
# Predicted: 699.70, Actual: 900.50
# Predicted: 968.89, Actual: 824.25
# Predicted: 907.64, Actual: 1406.00
# Predicted: 962.44, Actual: 930.00
# Predicted: 832.87, Actual: 769.50
# Predicted: 833.30, Actual: 757.00
# Predicted: 1230.48, Actual: 1443.75
# Predicted: 688.23, Actual: 495.00
# Predicted: 886.02, Actual: 1270.00
# Predicted: 701.77, Actual: 928.75
# Predicted: 1241.16, Actual: 1510.00
# Predicted: 743.26, Actual: 625.00
# Predicted: 859.02, Actual: 787.50
# Predicted: 776.21, Actual: 760.00
# Predicted: 1002.47, Actual: 1395.00
# Predicted: 1358.38, Actual: 1030.00
# Predicted: 773.88, Actual: 598.50
# Predicted: 749.62, Actual: 878.00
# Predicted: 875.19, Actual: 800.00
# Predicted: 866.76, Actual: 1840.25
# Predicted: 1404.35, Actual: 600.00
# Predicted: 1088.95, Actual: 1014.00
# Predicted: 825.14, Actual: 777.50
# Predicted: 864.99, Actual: 920.00
# Predicted: 1056.91, Actual: 579.00
# Predicted: 554.83, Actual: 785.00
# Predicted: 955.82, Actual: 1345.00
# Predicted: 1010.58, Actual: 975.00
# Predicted: 660.20, Actual: 1795.00
# Predicted: 1178.32, Actual: 602.75
# Predicted: 1239.54, Actual: 1494.00
# Predicted: 1390.27, Actual: 1325.00
# Predicted: 991.72, Actual: 565.00
# Predicted: 539.24, Actual: 749.75
# Predicted: 564.68, Actual: 730.25
# Predicted: 538.08, Actual: 1483.75
# Predicted: 228.54, Actual: 500.00
# Predicted: 841.08, Actual: 852.50
# Predicted: 800.30, Actual: 917.75
# Predicted: 752.85, Actual: 885.00
# Predicted: 1084.63, Actual: 658.25
# Predicted: 743.36, Actual: 625.00
# Predicted: 1001.63, Actual: 833.75
# Predicted: 1056.09, Actual: 1504.75
# Predicted: 1414.88, Actual: 1437.00
# Predicted: 789.45, Actual: 635.00
# Predicted: 1444.34, Actual: 1527.25
# Predicted: 765.51, Actual: 845.00
# Predicted: 786.58, Actual: 845.00
# Predicted: 805.31, Actual: 508.75
# Predicted: 1198.54, Actual: 1465.50
# Predicted: 725.96, Actual: 1297.50
# Predicted: 623.74, Actual: 1350.00
# Predicted: 796.00, Actual: 541.00
# Predicted: 1248.95, Actual: 670.25
# Predicted: 591.18, Actual: 545.00
# Predicted: 1045.48, Actual: 1368.75
# Predicted: 1107.77, Actual: 1469.25
# Predicted: 922.56, Actual: 1462.00
# Predicted: 641.27, Actual: 740.75
# Predicted: 1150.17, Actual: 808.50
# Predicted: 1003.80, Actual: 665.00
# Predicted: 680.78, Actual: 658.00
# Predicted: 1118.10, Actual: 1448.25
# Predicted: 1010.45, Actual: 1269.75
# Predicted: 1391.86, Actual: 1516.50
# Predicted: 684.91, Actual: 625.00
# Predicted: 919.69, Actual: 1170.00
# Predicted: 1003.63, Actual: 959.00
# Predicted: 1012.90, Actual: 660.00
# Predicted: 765.61, Actual: 1435.00
# Predicted: 877.39, Actual: 780.00
# Predicted: 703.57, Actual: 827.50
# Predicted: 844.27, Actual: 900.00
# Predicted: 623.62, Actual: 576.00
# Predicted: 973.49, Actual: 858.75
# Predicted: 779.70, Actual: 1418.75
# Predicted: 913.86, Actual: 1337.75
# Predicted: 766.37, Actual: 790.00
# Predicted: 1073.95, Actual: 1090.00
# Predicted: 1065.78, Actual: 1486.25
# Predicted: 986.58, Actual: 1075.00
# Predicted: 981.72, Actual: 935.00
# Predicted: 831.65, Actual: 790.00
# Predicted: 822.39, Actual: 610.00
# Predicted: 959.51, Actual: 1441.25
# Predicted: 1385.17, Actual: 1380.00
# Predicted: 857.83, Actual: 842.50
# Predicted: 801.06, Actual: 849.50
# Predicted: 646.25, Actual: 765.00
# Predicted: 845.32, Actual: 728.00
# Predicted: 858.33, Actual: 971.50
# Predicted: 844.87, Actual: 1333.50
# Predicted: 707.54, Actual: 670.50
# Predicted: 938.03, Actual: 707.75
# Predicted: 735.37, Actual: 764.25
# Predicted: 1003.39, Actual: 1460.00
# Predicted: 839.62, Actual: 988.25
# Predicted: 740.25, Actual: 865.00
# Predicted: 908.35, Actual: 825.00
# Predicted: 1152.17, Actual: 1383.50
# Predicted: 831.98, Actual: 577.75
# Predicted: 830.32, Actual: 860.75
# Predicted: 637.67, Actual: 528.25
# Predicted: 1052.06, Actual: 1354.50
# Predicted: 907.77, Actual: 976.50
# Predicted: 627.46, Actual: 925.00
# Predicted: 939.00, Actual: 1365.25
# Predicted: 1056.09, Actual: 565.00
# Predicted: 1130.25, Actual: 1428.50
# Predicted: 1018.38, Actual: 520.00
# Predicted: 805.53, Actual: 825.00
# Predicted: 1178.73, Actual: 758.50
# Predicted: 879.60, Actual: 810.00
# Predicted: 866.54, Actual: 875.25
# Predicted: 1174.58, Actual: 577.75
# Predicted: 1329.59, Actual: 945.00
# Predicted: 1016.32, Actual: 579.00
# Predicted: 844.81, Actual: 874.75
# Predicted: 981.57, Actual: 1000.00
# Predicted: 963.20, Actual: 868.25
# Predicted: 828.59, Actual: 530.00
# Predicted: 746.66, Actual: 1330.00
# Predicted: 708.42, Actual: 800.00
# Predicted: 996.47, Actual: 635.00
# Predicted: 1018.65, Actual: 545.00
# Predicted: 1061.33, Actual: 1492.25
# Predicted: 701.78, Actual: 712.25
# Predicted: 849.86, Actual: 807.25
# Predicted: 914.62, Actual: 883.00
# Predicted: 710.43, Actual: 635.00
# Predicted: 697.38, Actual: 680.00
# Predicted: 470.83, Actual: 497.75
# Predicted: 659.74, Actual: 660.25
# Predicted: 1033.83, Actual: 1095.00
# Predicted: 1226.01, Actual: 551.75
# Predicted: 741.17, Actual: 773.75
# Predicted: 928.89, Actual: 943.25
# Predicted: 1075.57, Actual: 1315.00
# Predicted: 851.40, Actual: 870.00
# Predicted: 951.43, Actual: 880.00
# Predicted: 1242.09, Actual: 1270.25
# Predicted: 884.92, Actual: 1008.00
# Predicted: 1277.03, Actual: 1430.00
# Predicted: 1166.12, Actual: 580.00
# Predicted: 1025.67, Actual: 1241.50
# Predicted: 626.75, Actual: 786.00
# Predicted: 683.00, Actual: 675.00
# Predicted: 625.08, Actual: 675.00
# Predicted: 761.15, Actual: 755.00
# Predicted: 1259.01, Actual: 855.00
# Predicted: 1338.00, Actual: 1450.00
# Predicted: 954.99, Actual: 935.00
# Predicted: 681.26, Actual: 761.00
# Predicted: 904.78, Actual: 845.00
# Predicted: 1054.12, Actual: 1191.50
# Predicted: 470.07, Actual: 615.00
# Predicted: 1162.93, Actual: 1202.25
# Predicted: 1221.47, Actual: 1200.00
# Predicted: 1043.87, Actual: 1365.00
# Predicted: 785.58, Actual: 1390.00
# Predicted: 1262.61, Actual: 1176.25
# Predicted: 907.04, Actual: 695.00
# Predicted: 1020.20, Actual: 1115.75
# Predicted: 645.75, Actual: 862.75
# Predicted: 1198.06, Actual: 1254.50
# Predicted: 1474.26, Actual: 1532.50
# Predicted: 566.16, Actual: 1205.00
# Predicted: 1111.02, Actual: 1453.75
# Predicted: 920.59, Actual: 1255.00
# Predicted: 1024.72, Actual: 1486.50
# Predicted: 1176.20, Actual: 1285.00
# Predicted: 598.10, Actual: 567.50
# Predicted: 788.95, Actual: 726.00
# Predicted: 1346.06, Actual: 1395.00
# Predicted: 737.95, Actual: 869.50
# Predicted: 899.72, Actual: 972.25
# Predicted: 727.66, Actual: 542.75
# Predicted: 787.58, Actual: 755.00
# Predicted: 1049.52, Actual: 1487.50
# Predicted: 890.83, Actual: 646.00
# Predicted: 1066.41, Actual: 695.00
# Predicted: 762.02, Actual: 690.75
# Predicted: 972.83, Actual: 1490.50
# Predicted: 611.18, Actual: 576.00
# Predicted: 641.80, Actual: 690.00
# Predicted: 1158.96, Actual: 579.75
# Predicted: 926.88, Actual: 1435.00
# Predicted: 834.66, Actual: 1350.25
# Predicted: 992.46, Actual: 940.75
# Predicted: 878.52, Actual: 1424.25
# Predicted: 528.45, Actual: 680.50
# Predicted: 1510.49, Actual: 1439.25
# Predicted: 810.99, Actual: 1415.00
# Predicted: 1058.06, Actual: 1469.25
# Predicted: 1105.89, Actual: 710.00
# Predicted: 615.34, Actual: 1385.00
# Predicted: 827.58, Actual: 797.50
# Predicted: 827.73, Actual: 741.50
# Predicted: 934.93, Actual: 975.00
# Predicted: 1065.95, Actual: 762.00
# Predicted: 1408.04, Actual: 1335.00
# Predicted: 896.74, Actual: 924.25
# Predicted: 1540.48, Actual: 710.00
# Predicted: 1017.02, Actual: 624.25
# Predicted: 887.80, Actual: 560.00
# Predicted: 821.44, Actual: 726.00
# Predicted: 820.65, Actual: 1546.25
# Predicted: 881.78, Actual: 1455.00
# Predicted: 195.15, Actual: 564.75
# Predicted: 903.12, Actual: 730.00
# Predicted: 695.40, Actual: 770.00
# Predicted: 902.05, Actual: 1469.50
# Predicted: 738.12, Actual: 562.50
# Predicted: 914.53, Actual: 700.00
# Predicted: 563.98, Actual: 1185.00
# Predicted: 833.29, Actual: 1400.00
# Predicted: 944.68, Actual: 1375.00
# Predicted: 698.46, Actual: 635.50
# Predicted: 874.23, Actual: 1196.00
# Predicted: 796.71, Actual: 875.00
# Predicted: 1291.66, Actual: 1440.00
# Predicted: 917.37, Actual: 602.75
# Predicted: 841.59, Actual: 865.00
# Predicted: 734.89, Actual: 1495.50
# Predicted: 931.70, Actual: 781.50
# Predicted: 943.32, Actual: 1143.00
# Predicted: 1556.39, Actual: 1392.00
# Predicted: 941.41, Actual: 955.00
# Predicted: 806.72, Actual: 729.25
# Predicted: 715.31, Actual: 695.00
# Predicted: 846.62, Actual: 1085.00
# Predicted: 726.51, Actual: 699.00
# Predicted: 747.72, Actual: 785.00
# Predicted: 916.56, Actual: 1445.00
# Predicted: 956.91, Actual: 633.25
# Predicted: 963.74, Actual: 1075.00
# Predicted: 541.93, Actual: 584.75
# Predicted: 728.89, Actual: 769.00
# Predicted: 926.38, Actual: 929.25
# Predicted: 719.64, Actual: 671.75
# Predicted: 763.00, Actual: 656.00
# Predicted: 933.96, Actual: 780.00
# Predicted: 630.09, Actual: 610.00
# Predicted: 801.02, Actual: 810.00
# Predicted: 1036.56, Actual: 970.50
# Predicted: 867.66, Actual: 985.00
# Predicted: 657.29, Actual: 515.00
# Predicted: 825.13, Actual: 798.75
# Predicted: 838.68, Actual: 783.00
# Predicted: 1466.92, Actual: 1420.00
# Predicted: 979.06, Actual: 830.00
# Predicted: 1080.37, Actual: 595.00
# Predicted: 397.08, Actual: 539.50
# Predicted: 990.56, Actual: 880.00
# Predicted: 693.64, Actual: 980.00
# Predicted: 974.33, Actual: 1505.75
# Predicted: 755.36, Actual: 840.00
# Predicted: 895.48, Actual: 805.00
# Predicted: 1031.01, Actual: 552.75
# Predicted: 985.70, Actual: 570.75
# Predicted: 947.09, Actual: 915.00
# Predicted: 961.54, Actual: 916.25
# Predicted: 1404.77, Actual: 1327.25
# Predicted: 916.23, Actual: 750.00
# Predicted: 1506.30, Actual: 1426.25
# Predicted: 810.05, Actual: 897.50
# Predicted: 799.86, Actual: 855.00
# Predicted: 805.35, Actual: 530.00
# Predicted: 704.36, Actual: 605.00
# Predicted: 709.19, Actual: 711.25
# Predicted: 1128.88, Actual: 1185.50
# Predicted: 1054.58, Actual: 1379.00
# Predicted: 1157.72, Actual: 1700.00
# Predicted: 1137.55, Actual: 736.50
# Predicted: 905.00, Actual: 871.50
# Predicted: 769.99, Actual: 1560.00
# Predicted: 984.62, Actual: 1765.00
# Predicted: 858.23, Actual: 865.50
# Predicted: 745.31, Actual: 745.00
# Predicted: 803.74, Actual: 800.00
# Predicted: 1069.95, Actual: 513.00
# Predicted: 1306.94, Actual: 1415.00
# Predicted: 915.14, Actual: 735.50
# Predicted: 885.61, Actual: 1010.00
# Predicted: 943.19, Actual: 820.00
# Predicted: 970.08, Actual: 628.75
# Predicted: 1234.31, Actual: 640.00
# Predicted: 827.46, Actual: 840.25
# Predicted: 975.19, Actual: 858.75
# Predicted: 1372.94, Actual: 1430.00
# Predicted: 696.67, Actual: 700.00
# Predicted: 869.71, Actual: 970.00
# Predicted: 742.22, Actual: 1552.50
# Predicted: 823.44, Actual: 1475.00
# Predicted: 970.97, Actual: 941.75
# Predicted: 921.45, Actual: 936.00
# Predicted: 989.09, Actual: 1380.25
# Predicted: 936.98, Actual: 1000.00
# Predicted: 1311.87, Actual: 657.00
# Predicted: 1384.47, Actual: 1433.00
# Predicted: 955.16, Actual: 941.25
# Predicted: 860.89, Actual: 994.75
# Predicted: 841.20, Actual: 1464.25
# Predicted: 848.88, Actual: 610.00
# Predicted: 726.16, Actual: 1445.75
# Predicted: 936.58, Actual: 900.00
# Predicted: 903.35, Actual: 925.00
# Predicted: 931.20, Actual: 726.50
# Predicted: 1049.94, Actual: 825.00
# Predicted: 886.05, Actual: 905.00
# Predicted: 946.50, Actual: 611.00
# Predicted: 968.07, Actual: 877.50
# Predicted: 833.47, Actual: 615.75
# Predicted: 682.19, Actual: 610.00
# Predicted: 1024.67, Actual: 1454.75
# Predicted: 716.31, Actual: 855.00
# Predicted: 627.46, Actual: 778.75

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test_orig, y_pred)
print(r2)
# Out:
# 0.08738523721694946
